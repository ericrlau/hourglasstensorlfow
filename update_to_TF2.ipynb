# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# ### Update the entire tree

# %%
# update the .py files and copy all the other files to the outtree
# !tf_upgrade_v2 \
    --intree /Volumes/Stoage/hourglasstensorlfow/tf_1 \
    --outtree /Volumes/Stoage/hourglasstensorlfow/tf_2 \
    --reportfile tree_report.txt
# Out:
# INFO line 178:7: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 178:7: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 188:9: Renamed 'tf.arg_max' to 'tf.argmax'
# INFO line 191:44: Changed tf.to_int64 call to tf.cast(..., dtype=tf.int64).
# INFO line 191:73: Changed tf.to_int64 call to tf.cast(..., dtype=tf.int64).
# INFO line 197:10: Renamed 'tf.arg_max' to 'tf.argmax'
# INFO line 198:40: Changed tf.to_int64 call to tf.cast(..., dtype=tf.int64).
# INFO line 198:69: Changed tf.to_int64 call to tf.cast(..., dtype=tf.int64).
# INFO line 206:8: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 206:8: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# ...

# %% [markdown]
# ### Update a single file

# %%
# !tf_upgrade_v2 \
  --infile /Volumes/Stoage/hourglasstensorlfow/tf_1/hourglass_tiny.py \
  --outfile /Volumes/Stoage/hourglasstensorlfow/tf_1/hourglass_tiny_v2.py
# Out:
# INFO line 138:8: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 138:8: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 140:15: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 142:20: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 144:18: Renamed 'tf.placeholder' to 'tf.compat.v1.placeholder'
# INFO line 156:8: `name` passed to `name_scope`. Because you may be re-entering an existing scope, it is not safe to convert automatically,  the v2 name_scope does not support re-entering scopes by name.
#
# INFO line 156:8: Renamed 'tf.name_scope' to 'tf.compat.v1.name_scope'
# INFO line 158:17: Added keywords to args of function 'tf.reduce_mean'
# INFO line 160:17: Added keywords to args of function 'tf.reduce_mean'
# ...

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
    print(tf.test.gpu_device_name())
    print('-------')
else:
    print("Please install GPU version of TF")

# if tf.test.cpu_device_name():
#     print('Default GPU Device: {}'.format(tf.test.cpu_device_name))
#     print(tf.test.cpu_device_name())
#     print('-------')
# Out:
# Default GPU Device: /device:GPU:0
# /device:GPU:0
# -------
# 2021-10-20 15:46:07.797063: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-10-20 15:46:07.797105: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-10-20 15:46:07.797201: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
import sys

import tensorflow.keras
import pandas as pd
import tensorflow as tf

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
if gpu:
    print('GPU device name: ', tf.config.list_physical_devices('GPU'))
# Out:
# Tensor Flow Version: 2.6.0
# Keras Version: 2.6.0
#
# Python 3.8.12 | packaged by conda-forge | (default, Oct 12 2021, 21:50:38)
# [Clang 11.1.0 ]
# Pandas 1.3.3
# GPU is available
# GPU device name:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
